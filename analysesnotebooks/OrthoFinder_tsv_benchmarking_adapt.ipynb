# %%
import gzip, json
import os
from glob import iglob
import csv
import pickle
from collections import defaultdict

# %%
## OMA 'for_benchmarking directory'
workdir='/users/sprietob/mywork/OMAprimEnsembl20/for_benchmarking/'
#OMARP20, OMAAugustus20, OMAtopNCBI20, OMAprimNCBI20, OMAtopEnsembl20, OMAprimEnsembl20
## OrthoFinder dir
ordir='/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/'

# For RP20: '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/RP20/OrthoFinder/Results_Apr04_1/Orthologues/'
# For Augustus20: '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/Augustus20/OrthoFinder/Results_Apr05/Orthologues/'
# For NCBI top: '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/topNCBI20/longestisos/OrthoFinder/Results_Apr19/Orthologues/'
# For NCBI prim: '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primNCBI20/longestisos/OrthoFinder/Results_Apr19/Orthologues/
# For Ensembl prim: '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/'

# For Ensembl directories:
pickledir= ordir.split('primary')[0]+ 'genetotranscripts/'

# %%
with gzip.open(workdir+'mapping.json.gz','rt') as fh:
    data = json.load(fh)

gene_map = {k.split(' ')[0]: k for k in data['mapping'].keys()}

combosseen=[]
with open(ordir+ 'Total.tsv', 'wt') as outfile:
    for file in iglob(ordir + '**', recursive=True):
        if file==ordir+'Total.tsv':
            continue
        if os.path.isfile(file): # filter dirs
                with open(file, 'rt') as infile:
                    sp1=file.split('Orthologues_')[1].split('/')[0]
                    sp2=file.split('v__')[1].split('.tsv')[0]
                    if (sp1+'-'+sp2) not in combosseen:
                        combosseen.append(sp2+'-'+sp1)
                        print(file)
                        lines = infile.readlines()[1:]
                        for line in lines:
                            sp1o= (line.split('\t')[1])
                            sp2o= (line.split('\t')[2])
                            for o in sp1o.split(','):
                                newo=gene_map[o.strip()]
                                for i in sp2o.split(','):
                                    i= i.strip('\n')
                                    newi=gene_map[i.strip()]
                                    outfile.write(newo+'\t'+newi + '\n')
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SALTR.tsv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 7>()
#      21 sp2o= (line.split('\t')[2])
#      22 for o in sp1o.split(','):
# ---> 23     newo=gene_map[o.strip()]
#      24     for i in sp2o.split(','):
#      25         i= i.strip('\n')
#
# KeyError: 'ENSENLG00000009837.1'

# %%
with open(ordir+ 'Total.tsv', 'wt') as outfile:
    for file in iglob(ordir + '**', recursive=True):
        if file==ordir+'Total.tsv':
            continue
        if os.path.isfile(file):
            print(file)
            with open(file, 'rt') as infile:
                    sp1=file.split('Orthologues_')[1].split('/')[0]
                    sp2=file.split('v__')[1].split('.tsv')[0]
                    if (sp1+'-'+sp2) not in combosseen:
                        combosseen.append(sp2+'-'+sp1)
                        print(file)
                        lines = infile.readlines()[1:]
                        for line in lines:
                            sp1o= (line.split('\t')[1])
                            sp2o= (line.split('\t')[2])
                            for o in sp1o.split(','):
                                newo=gene_map[o.strip()]
                                for i in sp2o.split(','):
                                    i= i.strip('\n')
                                    newi=gene_map[i.strip()]
                                    outfile.write(newo+'\t'+newi + '\n')
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SALTR.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SARHA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__LEPOC.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORANA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__CHICK.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORYLA.tsv
# ...

# %%
for f in iglob(ordir + '**', recursive=False):
    print(f)
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ERCAL
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_XENTR
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_KAKAP
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_GADMO
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_HUMAN
# ...

# %%
genetotrans=defaultdict(str)
for file in iglob(pickledir+ '**'):
    if file.endswith('.p'):
        print(file)
        with open(file, 'rb') as currentdict:
            currentdict=pickle.load(currentdict)
        genetotrans.update(currentdict)
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/GADMO.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/SARHA.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/ORYLA.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/ERCAL.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/HUMAN.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/LEPOC.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/DANRE.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/CIOIN.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/KAKAP.p
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/genetotranscripts/XENTR.p
# ...

# %%
len(genetotrans)
# Out:
# 436716

# %%
## Ensembl primary (need to finish adapting)

with gzip.open(workdir+'mapping.json.gz','rt') as fh:
    data = json.load(fh)

gene_map = {k.split(' ')[0]: k for k in data['mapping'].keys()}

combosseen=[]
with open(ordir+ 'Total.tsv', 'wt') as outfile:
    for file in iglob(ordir + '**', recursive=True):
        if file==ordir+'Total.tsv':
            continue
        if os.path.isfile(file): # filter dirs
                with open(file, 'rt') as infile:
                    sp1=file.split('Orthologues_')[1].split('/')[0]
                    sp2=file.split('v__')[1].split('.tsv')[0]
                    print(file)
                    if (sp1+'-'+sp2) not in combosseen:
                        combosseen.append(sp2+'-'+sp1)
                        lines = infile.readlines()[1:]
                        for line in lines:
                            sp1o= (line.split('\t')[1])
                            sp2o= (line.split('\t')[2])
                            for g1 in sp1o.split(','):
                                ntrans1=genetotrans[g1.strip()]
                                newo=gene_map[ntrans1]
                                for g2 in sp2o.split(','):
                                    g2= g2.strip('\n')
                                    ntrans2=genetotrans[g2.strip()]
                                    if file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_CHPIB/CHPIB__v__MOUSE.tsv' or file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_SARHA/SARHA__v__MOUSE.tsv' or file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_PODMU/PODMU__v__MOUSE.tsv':
                                        if ntrans2=='ENSMUSP00000149101.1':
                                            continue
                                        else:
                                            newi=gene_map[ntrans2]
                                    else:
                                        newi=gene_map[ntrans2]
                                        
                                    outfile.write(newo+'\t'+newi + '\n')
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SALTR.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SARHA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__LEPOC.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORANA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__CHICK.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORYLA.tsv
# ...

# %%
##Ensembl top

with gzip.open(workdir+'mapping.json.gz','rt') as fh:
    data = json.load(fh)

gene_map = {k.split(' ')[0]: k for k in data['mapping'].keys()}

combosseen=[]
with open(ordir+ 'Total.tsv', 'wt') as outfile:
    for file in iglob(ordir + '**', recursive=True):
        if file==ordir+'Total.tsv':
            continue
        if os.path.isfile(file): # filter dirs
                with open(file, 'rt') as infile:
                    sp1=file.split('Orthologues_')[1].split('/')[0]
                    sp2=file.split('v__')[1].split('.tsv')[0]
                    print(file)
                    if (sp1+'-'+sp2) not in combosseen:
                        combosseen.append(sp2+'-'+sp1)
                        lines = infile.readlines()[1:]
                        for line in lines:
                            sp1o= (line.split('\t')[1])
                            sp2o= (line.split('\t')[2])
                            for g1 in sp1o.split(','):
                                ntrans1=genetotrans[g1.strip()]
                                newo=gene_map[ntrans1]
                                for g2 in sp2o.split(','):
                                    g2= g2.strip('\n')
                                    ntrans2=genetotrans[g2.strip()]
                                    if file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_CHPIB/CHPIB__v__MOUSE.tsv' or file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_SARHA/SARHA__v__MOUSE.tsv' or file == '/users/sprietob/mywork/orthofinder_runs/OrthoFinder/topEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_PODMU/PODMU__v__MOUSE.tsv':
                                        if ntrans2=='ENSMUSP00000149101.1':
                                            continue
                                        else:
                                            newi=gene_map[ntrans2]
                                    else:
                                        newi=gene_map[ntrans2]
                                        
                                    outfile.write(newo+'\t'+newi + '\n')
# Out:
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SALTR.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__SARHA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__LEPOC.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORANA.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__CHICK.tsv
# /users/sprietob/mywork/orthofinder_runs/OrthoFinder/primEnsembl20/primary_transcripts/OrthoFinder/Results_Apr05/Orthologues/Orthologues_ECNAU/ECNAU__v__ORYLA.tsv
# ...

# %%
print(len(combosseen))
# Out:
# 190

# %%
gene_map['ENSMUSP00000149101.1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 gene_map['ENSMUSP00000149101.1']
#
# KeyError: 'ENSMUSP00000149101.1'

# %%
gene_map['ENSMUSG00000062712.3']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 gene_map['ENSMUSG00000062712.3']
#
# KeyError: 'ENSMUSG00000062712.3'

# %%
gene_map['ENSGMOP00000046663.1']
# Out:
# 'ENSGMOP00000046663.1 pep primary_assembly:gadMor3.0:2:11626140:11626424:1 gene:ENSGMOG00000025554.1 transcript:ENSGMOT00000073315.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene'

# %%
gene_map = {k.split(' ')[0]: k for k in data['mapping'].keys()}

# %%
data['Goff']

# %%
data.keys()
# Out:
# dict_keys(['mapping', 'Goff', 'species', 'excluded_ids'])

# %%
list(data['mapping'].keys())[:10]
# Out:
# ['ENSGALP00000073247.1 pep chromosome:GRCg6a:15:8238927:8239208:1 gene:ENSGALG00000049010.1 transcript:ENSGALT00000103863.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene',
#  'ENSGALP00000067379.1 pep chromosome:GRCg6a:15:8237650:8237754:-1 gene:ENSGALG00000050761.1 transcript:ENSGALT00000092144.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene',
#  'ENSGALP00000069276.1 pep chromosome:GRCg6a:15:8236967:8237065:-1 gene:ENSGALG00000047343.1 transcript:ENSGALT00000097599.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene',
#  'ENSGALP00000066843.1 pep chromosome:GRCg6a:15:8236440:8236721:1 gene:ENSGALG00000049486.1 transcript:ENSGALT00000096074.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene',
#  'ENSGALP00000070257.1 pep chromosome:GRCg6a:15:8235870:8236154:-1 gene:ENSGALG00000052566.1 transcript:ENSGALT00000093123.1 gene_biotype:IG_V_gene transcript_biotype:IG_V_gene',
# ...

# %%
gene_map = {k.split(' ')[0]: k for k in data['mapping'].keys()}

# %%
list(gene_map.keys())[:10]
# Out:
# ['ENSGALP00000073247.1',
#  'ENSGALP00000067379.1',
#  'ENSGALP00000069276.1',
#  'ENSGALP00000066843.1',
#  'ENSGALP00000070257.1',
#  'ENSGALP00000066129.1',
#  'ENSGALP00000065849.1',
#  'ENSGALP00000059936.2',
#  'ENSGALP00000065903.1',
#  'ENSGALP00000033376.5']

# %%
gene_map['ENSENLP00000021587.1']
# Out:
# 'ENSENLP00000021587.1 pep primary_assembly:fEcheNa1.1:8:11285332:11285916:-1 gene:ENSENLG00000009837.1 transcript:ENSENLT00000022334.1 gene_biotype:protein_coding transcript_biotype:protein_coding'

# %%
combosseen=[]
with open(ordir+ 'Total.tsv', 'wt') as outfile:
    for file in iglob(ordir + '**', recursive=True):
        if file==ordir+'Total.tsv':
            continue
        if os.path.isfile(file): # filter dirs
                with open(file, 'rt') as infile:
                    sp1=file.split('Orthologues_')[1].split('/')[0]
                    sp2=file.split('v__')[1].split('.tsv')[0]
                    if (sp1+'-'+sp2) not in combosseen:
                        combosseen.append(sp2+'-'+sp1)
                        lines = infile.readlines()[1:]
                        for line in lines:
                            sp1o= (line.split('\t')[1])
                            sp2o= (line.split('\t')[2])
                            for o in sp1o.split(','):
                                newo=gene_map[o.strip()]
                                for i in sp2o.split(','):
                                    i= i.strip('\n')
                                    newi=gene_map[i.strip()]
                                    outfile.write(newo+'\t'+newi + '\n')
