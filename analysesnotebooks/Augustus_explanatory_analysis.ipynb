# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
spinfo=pd.read_csv('Species_info_paper.csv')
statsmerge=pd.read_csv('Statsmerge.csv')

# %%
statsmerge=statsmerge.drop(columns='Unnamed: 0')

# %%
statsmerge
# Out:
#    Species                       Method    count        mean         std  \
# 0    CIOIN                    Ab-initio  13196.0  587.237875  667.740078
# 1    CIOIN  Reference proteomes UniProt  16680.0  322.028777  347.341120
# 2    CIOIN                         NCBI  13627.0  512.347912  520.487474
# 3    CIOIN                      Ensembl  16671.0  321.240957  346.229801
# 4    LEPOC                    Ab-initio  36227.0  360.272283  416.437873
# ..     ...                          ...      ...         ...         ...
# 75   FELCA  Reference proteomes UniProt  19652.0  563.930389  554.057233
# 76   PHOSI  Reference proteomes UniProt  18892.0  536.783242  509.399713
# 77   PHOSI                         NCBI  19069.0  563.881535  583.314773
# 78   PHOSI                      Ensembl  18962.0  522.826179  495.894731
# 79   PHOSI                    Ab-initio  20209.0  505.287001  577.468482
#
#      min    25%    50%    75%      max  Orthologues_total  \
# 0   36.0  236.0  418.0  717.0  33420.0               6547
# 1   21.0  144.0  236.0  415.0  21338.0               7452
# 2   35.0  245.0  393.0  616.0  26404.0               8254
# 3   21.0  144.0  236.0  414.0  21338.0               7467
# 4   17.0  137.0  226.0  429.0  22541.0              15308
# ..   ...    ...    ...    ...      ...                ...
# 75  13.0  264.0  423.0  690.0  27108.0              18385
# 76  24.0  230.0  405.0  662.0   8798.0              17725
# 77  35.0  259.0  421.0  683.0  34346.0              18288
# 78  24.0  224.0  395.0  643.0   8798.0              17901
# 79  17.0  185.0  345.0  626.0  35688.0              14571
#
#     Relationships_total  Orthologs_norm  Relats_perOrth  Relats_perGene
# 0                100538        0.496135       15.356346        7.618824
# 1                178245        0.446763       23.919082       10.686151
# 2                247412        0.605709       29.974800       18.156014
# 3                185286        0.447904       24.813982       11.114270
# 4                179561        0.422558       11.729880        4.956552
# ..                  ...             ...             ...             ...
# 75               384469        0.935528       20.912102       19.563861
# 76               299045        0.938228       16.871368       15.829187
# 77               545257        0.959043       29.815015       28.593896
# 78               322722        0.944046       18.028155       17.019407
# 79               182486        0.721015       12.523917        9.029937
#
# [80 rows x 15 columns]

# %%
abin=statsmerge[statsmerge["Method"]=='Ab-initio']

# %%
abin=abin.reset_index(drop=True)

# %%
from pandas.api.types import CategoricalDtype
speciesorder = CategoricalDtype(['CIOIN', 'LEPOC', 'DANRE', 'SALTR', 'GADMO', 'ORYLA', 'ECNAU', 'ERCAL', 'XENTR', 'CHPIB', 'CHICK', 'KAKAP', 'TAEGU', 'PODMU', 'ORANA', 'SARHA', 'HUMAN', 'MOUSE', 'FELCA', 'PHOSI'], ordered=True)
spinfo['Code'] = spinfo['Code'].astype(speciesorder)
spinfo=spinfo.sort_values('Code')
spinfo.reset_index(drop=True)
# Out:
#                                      Class                  Order  \
# 0                               Ascidiacea         Phlebobranchia
# 1    Actinopterygii/ Actinopteri/ Holostei       Lepisosteiformes
# 2   Actinopterygii/ Actinopteri/ Teleostei          Cypriniformes
# 3   Actinopterygii/ Actinopteri/ Teleostei          Salmoniformes
# 4    Actinopterygii/ Actinopteri/ Holostei             Gadiformes
# 5   Actinopterygii/ Actinopteri/ Teleostei           Beloniformes
# 6   Actinopterygii/ Actinopteri/ Teleostei          Carangiformes
# 7                Actinopterygii/ Cladistii        Polypteriformes
# 8                  Sarcopterygii/ Amphibia                  Anura
# 9                  Sarcopterygii/ Reptilia             Testudines
# 10                                    Aves            Galliformes
# 11                                    Aves         Psittaciformes
# 12                     Sarcopterygii/ Aves          Passeriformes
# 13               Sarcopterygii/ Sauropsida               Squamata
# 14                  Sarcopterygii/Mammalia            Monotremata
# 15                                     NaN             Metatheria
# 16                 Sarcopterygii/ Mammalia               Primates
# 17                 Sarcopterygii/ Mammalia               Rodentia
# 18                 Sarcopterygii/ Mammalia              Carnivora
# 19                 Sarcopterygii/ Mammalia  Artiodactyla/ cetacea
#
#                Family   Code Closest Augustus species  \
# 0            Cionidae  CIOIN                    ciona
# 1       Lepisosteidae  LEPOC                zebrafish
# 2          Cyprinidae  DANRE                zebrafish
# 3          Salmonidae  SALTR                zebrafish
# 4             Gadidae  GADMO                zebrafish
# 5    Adrianichthyidae  ORYLA                zebrafish
# 6          Echeneidae  ECNAU                zebrafish
# 7        Polypteridae  ERCAL                zebrafish
# 8             Pipidae  XENTR                    human
# 9            Emydidae  CHPIB                  chicken
# 10        Phasianidae  CHICK                  chicken
# 11        Strigopidae  KAKAP                  chicken
# 12        Estrildidae  TAEGU                  chicken
# 13           Agamidae  PODMU                  chicken
# 14  Ornithorhynchidae  ORANA                    human
# 15                NaN  SARHA                    human
# 16          Hominidae  HUMAN                    human
# 17            Muridae  MOUSE                    human
# 18                NaN  FELCA                    human
# 19        Phocoenidae  PHOSI                    human
#
#     Median divergence time estimate (MYa)                       Name  \
# 0                                       0         ciona intestinalis
# 1                                     321       lepisosteus oculatus
# 2                                       0                danio rerio
# 3                                     224               salmo trutta
# 4                                     224               gadus morhua
# 5                                     224            oryzias latipes
# 6                                     224         echeneis naucrates
# 7                                     396  erpetoichthys calabaricus
# 8                                     352         xenopus tropicalis
# 9                                     261     chrysemys picta bellii
# 10                                      0              gallus gallus
# 11                                     91        strigops habroptila
# 12                                     91        taeniopygia guttata
# 13                                    280           podarcis muralis
# 14                                    180   ornithorhynchus anatinus
# 15                                    160       sarcophilus harrisii
# 16                                      0               homo sapiens
# 17                                     87               mus musculus
# 18                                     94                felis catus
# 19                                     94             phocoena sinus
#
#                                               Species  Taxon ID  \
# 0                                  Ciona intestinalis      7719
# 1                  Lepisosteus oculatus (spotted gar)      7918
# 2                                         Danio rerio      7955
# 3                          Salmo trutta (brown trout)      8032
# 4                        Gadus morhua (atlantic cod?)      8049
# 5   Oryzias latipes (Japanese rice fish/ medaka fish)      8090
# 6               Echeneis naucrates (live sharksucker)    173247
# 7                Erpetoichthys calabaricus (reedfish)     27687
# 8            Xenopus tropicalis (western clawed frog)      8364
# 9                              Chrysemys picta bellii      8478
# 10                                      Gallus gallus      9031
# 11                       Strigops habroptila (kakapo)   2489341
# 12                  Taeniopygia guttata (zebra finch)     59729
# 13                     Podarcis muralis (wall lizard)     64176
# 14                Ornithorhynchus anatinus (platypus)      9258
# 15             Sarcophilus harrisii (tasmanian devil)      9305
# 16                                       Homo sapiens      9606
# 17                                       Mus musculus     10090
# 18                         Felis catus (domestic cat)      9685
# 19                           Phocoena sinus (vaquita)     42100
#
#                                              Assembly  ... Uniprot RefProt  \
# 0   https://www.ebi.ac.uk/ena/browser/view/GCA_000...  ...     UP000008144
# 1                            LepOcu1, GCA_000242695.1  ...     UP000018468
# 2   https://www.ncbi.nlm.nih.gov/assembly/GCA_0000...  ...     UP000000437
# 3               fSalTru1.1, GCA_901001165.1, Jun 2019  ...     UP000472277
# 4                          gadMor3.0, GCA_902167405.1  ...     UP000694546
# 5            ASM223467v1, GCA_002234675.1, Jul 2017.   ...     UP000001038
# 6               fEcheNa1.1, GCA_900963305.1, Apr 2019  ...     UP000472264
# 7              fErpCal1.1,  GCA_900747795.2, Mar 2019  ...     UP000694620
# 8            UCB_Xtro_10.0, GCA_000004195.4, Nov 2019  ...     UP000008143
# 9   Chrysemys_picta_bellii-3.0.3, GCA_000241765.2,...  ...     UP000694380
# 10                  GRCg6a, GCA_000002315.5, Mar 2018  ...     UP000000539
# 11  bStrHab1_v1.p, INSDC Assembly GCA_004027225.1,...  ...     UP000472266
# 12                     bTaeGut1_v1.p, GCA_003957565.2  ...     UP000007754
# 13              PodMur_1.0, GCA_004329235.1, Mar 2019  ...     UP000472272
# 14  mOrnAna1.p.v1, GCA_004115215.2, May 2019 (not ...  ...     UP000002279
# 15             mSarHar1.11, GCA_902635505.1, Nov 2019  ...     UP000007648
# 16  https://www.ncbi.nlm.nih.gov/assembly/GCF_0000...  ...     UP000005640
# 17  https://www.ncbi.nlm.nih.gov/assembly/GCA_0000...  ...     UP000000589
# 18        Felis_catus_9.0,  GCA_000181335.4, Nov 2017  ...     UP000011712
# 19  mPhoSin1.pri, INSDC Assembly GCA_008692025.1, ...  ...     UP000694554
#
#                             Origin  \
# 0         Ensembl, GCA_000224145.1
# 1     GCA_000242695.1 from Ensembl
# 2                          Ensembl
# 3       Ensembl, \nGCA_901001165.1
# 4     GCA_902167405.1 from Ensembl
# 5       Ensembl, \nGCA_002234675.1
# 6       Ensembl, \nGCA_900963305.1
# 7       Ensembl, GCA_900747795.2\n
# 8      GCF_000004195.4 from Refseq
# 9   GCA_000241765.2 from Ensembl\n
# 10        Ensembl, GCA_000002315.5
# 11  \nGCA_004027225.1 from Ensembl
# 12    GCA_003957565.2 from Ensembl
# 13      Ensembl, \nGCA_004329235.1
# 14    GCA_004115215.2 from Ensembl
# 15      Ensembl, \nGCA_902635505.1
# 16     Ensembl, \nGCA_000001405.27
# 17      Ensembl, \nGCA_000001635.8
# 18     Ensembl, \nGCA_000181335.4
# 19     Ensembl, \nGCA_008692025.1
#
#                                               Details      Gene count  \
# 0                                                 NaN           16680
# 1                                    Also QfO RefProt             NaN
# 2          I am using the previous zfish (april/may?)  25,707 /20,366
# 3                                                 NaN          43,230
# 4   OMARK: missing 9% genes? (Acanthomorphata). BE...             NaN
# 5                                                 NaN          23,617
# 6                                                 NaN          21,548
# 7                                                 NaN          20,085
# 8                             BUSCO: 49.2% duplicated          22,099
# 9                                BUSCO: all missing??             NaN
# 10                                                NaN          18,108
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN          21,928
# 14                                                NaN             NaN
# 15                                                NaN          19,171
# 16                                                NaN          20,601
# 17                                                NaN          21,984
# 18                                                NaN          19,652
# 19                                                NaN          18,892
#
#    Reviewed (Swiss-P) Prot count  2022_02 assembly previous assembly   \
# 0                  27     17,311   GCA_000224145.1    GCA_000224145.1
# 1                 NaN        NaN               NaN                NaN
# 2                3242     46,687   GCF_000002035.6    GCA_000002035.4
# 3                   6    114,752               NaN                NaN
# 4                 NaN        NaN               NaN                NaN
# 5                  91     36,128               NaN                NaN
# 6                   0     54,685               NaN                NaN
# 7                  13     41,870               NaN                NaN
# 8               1,709     37,716               NaN                NaN
# 9                 NaN        NaN               NaN                NaN
# 10              2,301      27530   GCA_000002315.5    GCA_000002315.5
# 11                NaN        NaN               NaN                NaN
# 12                NaN        NaN               NaN                NaN
# 13                  0     36,445               NaN                NaN
# 14                NaN        NaN               NaN                NaN
# 15                  3     36,286               NaN                NaN
# 16             20,383      79740  GCA_000001405.27   GCA_000001405.27
# 17              17120     55,315   GCA_000001635.8    GCA_000001635.8
# 18                232    40, 213               NaN                NaN
# 19                  1     21,318               NaN                NaN
#
#     2022_02 source  previous source
# 0          Ensembl          Ensembl
# 1              NaN              NaN
# 2           Refseq          Ensembl
# 3              NaN              NaN
# 4              NaN              NaN
# 5              NaN              NaN
# 6              NaN              NaN
# 7              NaN              NaN
# 8              NaN              NaN
# 9              NaN              NaN
# 10         Ensembl          Ensembl
# 11             NaN              NaN
# 12             NaN              NaN
# 13             NaN              NaN
# 14             NaN              NaN
# 15             NaN              NaN
# 16         Ensembl          Ensembl
# 17         Ensembl          Ensembl
# 18             NaN              NaN
# 19             NaN              NaN
#
# [20 rows x 42 columns]

# %%
abin['Species']= abin['Species'].astype(speciesorder)
abin=abin.sort_values('Species')
abin=abin.reset_index(drop=True)

# %%
augspelist=list(spinfo['Closest Augustus species'])
spdivergence=list(spinfo['Median divergence time estimate (MYa)'])
nscaffolds=list(spinfo['N scaffolds'])
ncontigs=list(spinfo['N Contigs'])

# %%
abin['Divergence-time']=spdivergence
abin['NScaffolds']=nscaffolds
abin['NContigs']=ncontigs
abin['Parameters species']=augspelist

# %%
abin
# Out:
#    Species     Method    count        mean         std   min     25%    50%  \
# 0    CIOIN  Ab-initio  13196.0  587.237875  667.740078  36.0  236.00  418.0
# 1    LEPOC  Ab-initio  36227.0  360.272283  416.437873  17.0  137.00  226.0
# 2    DANRE  Ab-initio  23288.0  572.593653  656.834187   1.0  232.00  405.0
# 3    SALTR  Ab-initio  51185.0  508.474553  560.288128   2.0  182.00  351.0
# 4    GADMO  Ab-initio  38909.0  425.787093  474.394888   7.0  151.00  289.0
# 5    ORYLA  Ab-initio  33024.0  453.040728  544.681967  66.0  157.00  298.0
# 6    ECNAU  Ab-initio  25404.0  549.279523  601.809214  19.0  194.75  383.0
# 7    ERCAL  Ab-initio  78579.0  249.338347  257.867127   3.0  114.00  169.0
# 8    XENTR  Ab-initio  40554.0  442.507052  542.063947  41.0  154.00  303.0
# 9    CHPIB  Ab-initio  91991.0  293.629268  297.042868   5.0  140.00  211.0
# 10   CHICK  Ab-initio  18050.0  540.498837  611.956700  28.0  216.00  376.0
# 11   KAKAP  Ab-initio  17022.0  551.134121  608.594017  49.0  216.00  389.0
# 12   TAEGU  Ab-initio  16880.0  562.503791  621.809784  50.0  227.00  403.0
# 13   PODMU  Ab-initio  34673.0  439.833877  470.676266  20.0  175.00  314.0
# 14   ORANA  Ab-initio  19661.0  500.861197  541.002494  10.0  188.00  345.0
# 15   SARHA  Ab-initio  16843.0  578.718934  628.424231  60.0  241.00  402.0
# 16   HUMAN  Ab-initio  22780.0  498.954785  581.116384  66.0  185.00  339.0
# 17   MOUSE  Ab-initio  23548.0  503.717343  566.019131  66.0  189.00  334.0
# 18   FELCA  Ab-initio  23355.0  473.007964  568.226354   2.0  165.00  315.0
# 19   PHOSI  Ab-initio  20209.0  505.287001  577.468482  17.0  185.00  345.0
#
#       75%      max  Orthologues_total  Relationships_total  Orthologs_norm  \
# 0   717.0  33420.0               6547               100538        0.496135
# 1   429.0  22541.0              15308               179561        0.422558
# 2   705.0  44005.0              19222               308132        0.825404
# 3   630.0  29370.0              35429               463848        0.692175
# 4   526.0  21989.0              21783               298865        0.559845
# 5   558.0  33977.0              19967               260107        0.604621
# 6   688.0  23170.0              18970               267270        0.746733
# 7   292.0  16208.0              17056               340778        0.217055
# 8   530.0  35366.0              18439               367643        0.454678
# 9   341.0  21620.0              37691               547473        0.409725
# 10  665.0  37618.0              14715               264547        0.815235
# 11  672.0  32566.0              14174               221649        0.832687
# 12  691.0  36758.0              14530               203854        0.860782
# 13  536.0  21610.0              20026               305964        0.577568
# 14  613.0  16745.0              14016               235159        0.712883
# 15  711.0  36340.0              14001               220450        0.831265
# 16  606.0  37139.0              16933               242446        0.743327
# 17  612.0  27482.0              17238               316231        0.732037
# 18  579.0  36380.0              15340               247631        0.656819
# 19  626.0  35688.0              14571               182486        0.721015
#
#     Relats_perOrth  Relats_perGene  Divergence-time NScaffolds NContigs  \
# 0        15.356346        7.618824                0       1280    6,381
# 1        11.729880        4.956552              321      2,105   45,199
# 2        16.030174       13.231364                0      1,917   19,725
# 3        13.092325        9.062186              224      1,441    5,378
# 4        13.720103        7.681128              224        226    1,441
# 5        13.026844        7.876302              224         24      515
# 6        14.089088       10.520784              224         38      178
# 7        19.979948        4.336757              396        169     1600
# 8        19.938337        9.065518              352        166      850
# 9        14.525298        5.951376              261     76,427  260,697
# 10       17.978050       14.656343                0        524    1,402
# 11       15.637717       13.021325               91         90      457
# 12       14.029869       12.076659               91        199      551
# 13       15.278338        8.824272              280       2160  714,612
# 14       16.777897       11.960684              180        322      834
# 15       15.745304       13.088523              160        105      444
# 16       14.317959       10.642932                0        472      998
# 17       18.344994       13.429208               87        102      306
# 18       16.142829       10.602912               94        767    1,138
# 19       12.523917        9.029937               94         65      273
#
#    Parameters species
# 0               ciona
# 1           zebrafish
# 2           zebrafish
# 3           zebrafish
# 4           zebrafish
# 5           zebrafish
# 6           zebrafish
# 7           zebrafish
# 8               human
# 9             chicken
# 10            chicken
# 11            chicken
# 12            chicken
# 13            chicken
# 14              human
# 15              human
# 16              human
# 17              human
# 18              human
# 19              human

# %%
especies=['CIOIN','ERCAL','LEPOC','DANRE','SALTR','GADMO','ECNAU', 'ORYLA', 'XENTR', 'PODMU', 'CHPIB', 
          'CHICK', 'TAEGU', 'KAKAP', 'ORANA', 'SARHA', 'PHOSI', 'FELCA', 'MOUSE', 'HUMAN']
trainingsp=['ciona', 'zebrafish', 'human', 'chicken']
mes=['Ab-initio', 'Reference proteomes UniProt', 'Ensembl', 'NCBI']

# %%
from pandas.api.types import CategoricalDtype

speciesorder = CategoricalDtype(especies, ordered=True)
abin['Species'] = abin['Species'].astype(speciesorder)
abin=abin.sort_values('Species')

# %%
from pandas.api.types import CategoricalDtype

speciesorder = CategoricalDtype(especies, ordered=True)
statsmerge['Species'] = statsmerge['Species'].astype(speciesorder)
#statsmerge=statsmerge.sort_values('Species')

# %%
statsmerge
# Out:
#    Species                       Method    count        mean         std  \
# 0    CIOIN                    Ab-initio  13196.0  587.237875  667.740078
# 1    CIOIN  Reference proteomes UniProt  16680.0  322.028777  347.341120
# 2    CIOIN                         NCBI  13627.0  512.347912  520.487474
# 3    CIOIN                      Ensembl  16671.0  321.240957  346.229801
# 4    LEPOC                    Ab-initio  36227.0  360.272283  416.437873
# ..     ...                          ...      ...         ...         ...
# 75   FELCA  Reference proteomes UniProt  19652.0  563.930389  554.057233
# 76   PHOSI  Reference proteomes UniProt  18892.0  536.783242  509.399713
# 77   PHOSI                         NCBI  19069.0  563.881535  583.314773
# 78   PHOSI                      Ensembl  18962.0  522.826179  495.894731
# 79   PHOSI                    Ab-initio  20209.0  505.287001  577.468482
#
#      min    25%    50%    75%      max  Orthologues_total  \
# 0   36.0  236.0  418.0  717.0  33420.0               6547
# 1   21.0  144.0  236.0  415.0  21338.0               7452
# 2   35.0  245.0  393.0  616.0  26404.0               8254
# 3   21.0  144.0  236.0  414.0  21338.0               7467
# 4   17.0  137.0  226.0  429.0  22541.0              15308
# ..   ...    ...    ...    ...      ...                ...
# 75  13.0  264.0  423.0  690.0  27108.0              18385
# 76  24.0  230.0  405.0  662.0   8798.0              17725
# 77  35.0  259.0  421.0  683.0  34346.0              18288
# 78  24.0  224.0  395.0  643.0   8798.0              17901
# 79  17.0  185.0  345.0  626.0  35688.0              14571
#
#     Relationships_total  Orthologs_norm  Relats_perOrth  Relats_perGene
# 0                100538        0.496135       15.356346        7.618824
# 1                178245        0.446763       23.919082       10.686151
# 2                247412        0.605709       29.974800       18.156014
# 3                185286        0.447904       24.813982       11.114270
# 4                179561        0.422558       11.729880        4.956552
# ..                  ...             ...             ...             ...
# 75               384469        0.935528       20.912102       19.563861
# 76               299045        0.938228       16.871368       15.829187
# 77               545257        0.959043       29.815015       28.593896
# 78               322722        0.944046       18.028155       17.019407
# 79               182486        0.721015       12.523917        9.029937
#
# [80 rows x 15 columns]

# %%
abin=abin.reset_index(drop=True)

# %%
trainingsp=['ciona', 'zebrafish', 'human', 'chicken']
trspeciestype = CategoricalDtype(trainingsp)
abin['Parameters species'] = abin['Parameters species'].astype(trspeciestype)

# %%
corr=pd.DataFrame({'Code': ['CIOIN', 'LEPOC', 'DANRE', 'SALTR', 'GADMO', 'ORYLA', 'ECNAU', 'ERCAL', 'XENTR', 'CHPIB', 'CHICK', 'KAKAP', 
                            'TAEGU', 'PODMU', 'ORANA', 'SARHA', 'HUMAN', 'MOUSE', 'FELCA', 'PHOSI'],
                   'Especies': ['C. intestinalis (vase tunicate)', 'L. oculatus (spotted gar)', 'D. rerio (zebrafish)', 
              'S. trutta (brown trout)','G. morhua (Atlantic cod)', 'O. latipes (medaka fish)', 'E. naucrates (live sharksucker)',
              'E. calabaricus (reedfish)', 'X. tropicalis (western clawed frog)', 'C. p. bellii (painted turtle)',
              'G. gallus (chicken)', 'S. habroptila (kakapo)', 'T. guttata (zebra finch)', 
              'P. muralis (wall lizard)','O. anatinus (platypus)', 'S. harrisii (tasmanian devil)', 
              'H. sapiens (human)', 'M. musculus (house mouse)', 'F. catus (domestic cat)', 'P. sinus (vaquita)']})

# %%
corrm=pd.DataFrame({'Me': ['Ab-initio', 'Reference proteomes UniProt', 'Ensembl', 'NCBI'],
                   'Method': ['Ab-initio', 'UniProt', 'Ensembl', 'NCBI']})

# %%
parsp=pd.DataFrame({'Name':['ciona', 'zebrafish', 'human', 'chicken'],
                   'Parsp': ['C. intestinalis (vase tunicate)', 'D. rerio (zebrafish)', 'H. sapiens (human)',
                            'G. gallus (chicken)']})

# %%
abin['Parameters species']= abin['Parameters species'].map(parsp.set_index('Name')['Parsp'])

# %%
abin['Species']= abin['Species'].map(corr.set_index('Code')['Especies'])

# %%
statsmerge['Species']= statsmerge['Species'].map(corr.set_index('Code')['Especies'])

# %%
methodsorder = CategoricalDtype(mes, ordered=True)
statsmerge['Method'] = statsmerge['Method'].astype(methodsorder)
statsmerge['Method']= statsmerge['Method'].map(corrm.set_index('Me')['Method'])

# %%
abin
# Out:
#                                 Species     Method    count        mean  \
# 0       C. intestinalis (vase tunicate)  Ab-initio  13196.0  587.237875
# 1             E. calabaricus (reedfish)  Ab-initio  78579.0  249.338347
# 2             L. oculatus (spotted gar)  Ab-initio  36227.0  360.272283
# 3                  D. rerio (zebrafish)  Ab-initio  23288.0  572.593653
# 4               S. trutta (brown trout)  Ab-initio  51185.0  508.474553
# 5              G. morhua (Atlantic cod)  Ab-initio  38909.0  425.787093
# 6       E. naucrates (live sharksucker)  Ab-initio  25404.0  549.279523
# 7              O. latipes (medaka fish)  Ab-initio  33024.0  453.040728
# 8   X. tropicalis (western clawed frog)  Ab-initio  40554.0  442.507052
# 9              P. muralis (wall lizard)  Ab-initio  34673.0  439.833877
# 10        C. p. bellii (painted turtle)  Ab-initio  91991.0  293.629268
# 11                  G. gallus (chicken)  Ab-initio  18050.0  540.498837
# 12             T. guttata (zebra finch)  Ab-initio  16880.0  562.503791
# 13               S. habroptila (kakapo)  Ab-initio  17022.0  551.134121
# 14               O. anatinus (platypus)  Ab-initio  19661.0  500.861197
# 15        S. harrisii (tasmanian devil)  Ab-initio  16843.0  578.718934
# 16                   P. sinus (vaquita)  Ab-initio  20209.0  505.287001
# 17              F. catus (domestic cat)  Ab-initio  23355.0  473.007964
# 18            M. musculus (house mouse)  Ab-initio  23548.0  503.717343
# 19                   H. sapiens (human)  Ab-initio  22780.0  498.954785
#
#            std   min     25%    50%    75%      max  Orthologues_total  \
# 0   667.740078  36.0  236.00  418.0  717.0  33420.0               6547
# 1   257.867127   3.0  114.00  169.0  292.0  16208.0              17056
# 2   416.437873  17.0  137.00  226.0  429.0  22541.0              15308
# 3   656.834187   1.0  232.00  405.0  705.0  44005.0              19222
# 4   560.288128   2.0  182.00  351.0  630.0  29370.0              35429
# 5   474.394888   7.0  151.00  289.0  526.0  21989.0              21783
# 6   601.809214  19.0  194.75  383.0  688.0  23170.0              18970
# 7   544.681967  66.0  157.00  298.0  558.0  33977.0              19967
# 8   542.063947  41.0  154.00  303.0  530.0  35366.0              18439
# 9   470.676266  20.0  175.00  314.0  536.0  21610.0              20026
# 10  297.042868   5.0  140.00  211.0  341.0  21620.0              37691
# 11  611.956700  28.0  216.00  376.0  665.0  37618.0              14715
# 12  621.809784  50.0  227.00  403.0  691.0  36758.0              14530
# 13  608.594017  49.0  216.00  389.0  672.0  32566.0              14174
# 14  541.002494  10.0  188.00  345.0  613.0  16745.0              14016
# 15  628.424231  60.0  241.00  402.0  711.0  36340.0              14001
# 16  577.468482  17.0  185.00  345.0  626.0  35688.0              14571
# 17  568.226354   2.0  165.00  315.0  579.0  36380.0              15340
# 18  566.019131  66.0  189.00  334.0  612.0  27482.0              17238
# 19  581.116384  66.0  185.00  339.0  606.0  37139.0              16933
#
#     Relationships_total  Orthologs_norm  Relats_perOrth  Relats_perGene  \
# 0                100538        0.496135       15.356346        7.618824
# 1                340778        0.217055       19.979948        4.336757
# 2                179561        0.422558       11.729880        4.956552
# 3                308132        0.825404       16.030174       13.231364
# 4                463848        0.692175       13.092325        9.062186
# 5                298865        0.559845       13.720103        7.681128
# 6                267270        0.746733       14.089088       10.520784
# 7                260107        0.604621       13.026844        7.876302
# 8                367643        0.454678       19.938337        9.065518
# 9                305964        0.577568       15.278338        8.824272
# 10               547473        0.409725       14.525298        5.951376
# 11               264547        0.815235       17.978050       14.656343
# 12               203854        0.860782       14.029869       12.076659
# 13               221649        0.832687       15.637717       13.021325
# 14               235159        0.712883       16.777897       11.960684
# 15               220450        0.831265       15.745304       13.088523
# 16               182486        0.721015       12.523917        9.029937
# 17               247631        0.656819       16.142829       10.602912
# 18               316231        0.732037       18.344994       13.429208
# 19               242446        0.743327       14.317959       10.642932
#
#     Divergence-time NScaffolds NContigs               Parameters species
# 0                 0       1280    6,381  C. intestinalis (vase tunicate)
# 1               396        169     1600             D. rerio (zebrafish)
# 2               321      2,105   45,199             D. rerio (zebrafish)
# 3                 0      1,917   19,725             D. rerio (zebrafish)
# 4               224      1,441    5,378             D. rerio (zebrafish)
# 5               224        226    1,441             D. rerio (zebrafish)
# 6               224         38      178             D. rerio (zebrafish)
# 7               224         24      515             D. rerio (zebrafish)
# 8               352        166      850               H. sapiens (human)
# 9               280       2160  714,612              G. gallus (chicken)
# 10              261     76,427  260,697              G. gallus (chicken)
# 11                0        524    1,402              G. gallus (chicken)
# 12               91        199      551              G. gallus (chicken)
# 13               91         90      457              G. gallus (chicken)
# 14              180        322      834               H. sapiens (human)
# 15              160        105      444               H. sapiens (human)
# 16               94         65      273               H. sapiens (human)
# 17               94        767    1,138               H. sapiens (human)
# 18               87        102      306               H. sapiens (human)
# 19                0        472      998               H. sapiens (human)

# %% [markdown]
# ##### Figure S3

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(20,12))
ax1=sns.scatterplot(data=abin, x='Divergence-time', y='Orthologs_norm', hue='Parameters species', s=80)
for i, txt in enumerate(abin['Species']):
    xpos= abin['Divergence-time'][i]
    ypos=abin['Orthologs_norm'][i]
    fs=12
    if txt == "C. p. bellii (painted turtle)":
        ax.annotate(txt, (xpos + 4, ypos-0.007), fontsize=fs)
    elif txt== "D. rerio (zebrafish)":
        ax.annotate(txt, (xpos + 4, ypos-0.001), fontsize=fs)
    elif txt== "G. gallus (chicken)":
        ax.annotate(txt, (xpos + 4, ypos-0.006), fontsize=fs)
    elif txt== "M. musculus (house mouse)":
        ax.annotate(txt, (xpos + 4, ypos-0.001), fontsize=fs)
    elif txt== "P. sinus (vaquita)":
        ax.annotate(txt, (xpos + 4, ypos-0.006), fontsize=fs)
    else:
        ax.annotate(txt, (xpos + 4, ypos-0.003), fontsize=fs)
        
        
# Pearson's correlation
rp, pp = sp.stats.pearsonr(x=abin['Divergence-time'], y=abin['Orthologs_norm'])

## Correlation line
import numpy as np
m, b = np.polyfit(abin['Divergence-time'], abin['Orthologs_norm'], 1)
X_plot = np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '-', c='pink')

plt.annotate('r'' = {:.2f}'.format(rp) + ', p = {:.3f}'.format(pp), xy=(0.30, 0.4), 
             xycoords='axes fraction', fontsize=22)

ax.set_xlim(-10,450)
sns.despine()
ax.set_ylabel('Proportion of orthologous proteins', labelpad =22, size =22)
ax.set_xlabel('Approximate divergence time (MYa) with parameters species', labelpad=22, size=22)
plt.legend(bbox_to_anchor=(0.05, 0.05), loc='lower left', fontsize=18,
           title= "Parameters species", title_fontsize=18)

plt.yticks(fontsize=20)
plt.xticks(fontsize=20)

#plt.savefig('Augustus-ProportionOrthologs-Divergencetime-CORR.png', bbox_inches="tight", dpi=300)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.]),
#  [Text(-100.0, 0, '−100'),
#   Text(0.0, 0, '0'),
#   Text(100.0, 0, '100'),
#   Text(200.0, 0, '200'),
#   Text(300.0, 0, '300'),
#   Text(400.0, 0, '400'),
#   Text(500.0, 0, '500')])

# %% [markdown]
# ##### Figure S1

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(20,12))
ax1=sns.scatterplot(data=abin, x='Divergence-time', y='count', hue='Parameters species', s=80)
for i, txt in enumerate(abin['Species']):
    xpos= abin['Divergence-time'][i]
    ypos=abin['count'][i]
    fs=13.5
    if txt =="D. rerio (zebrafish)":
        ax.annotate(txt, (xpos -5, ypos+1200), fontsize=fs)
    elif txt== "M. musculus (house mouse)":
        ax.annotate(txt, (xpos -10, ypos+1600), fontsize=fs)
    elif txt == "T. guttata (zebra finch)":
        ax.annotate(txt, (xpos-5, ypos-1800), fontsize=fs)
        
    elif txt == "S. habroptila (kakapo)":
        ax.annotate(txt, (xpos+4, ypos), fontsize=fs)
    else:
        ax.annotate(txt, (xpos + 4, ypos-800), fontsize=fs)

# Pearson's correlation
rp, pp = sp.stats.pearsonr(x=abin['Divergence-time'], y=abin['count'])


## Correlation line
import numpy as np
m, b = np.polyfit(abin['Divergence-time'], abin['count'], 1)
X_plot = np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '-', c='pink')

plt.annotate('r'' = {:.2f}'.format(rp) + ', p = {:.3f}'.format(pp), xy=(0.25, 0.4), 
             xycoords='axes fraction', fontsize=22)


ax.set_xlim(-10,450)
sns.despine()
ax.set_ylabel('Number of proteins', labelpad =22, size =20)
ax.set_xlabel('Approximate divergence time (MYa) with parameters species', labelpad=22, size=20)
plt.legend(bbox_to_anchor=(0.05, 0.85), loc='upper left', fontsize=18,
           title= "Parameters species", title_fontsize=18)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
#plt.savefig('Augustus-Nproteins-divergencetime_correl.png', bbox_inches="tight", dpi=300)

# %%
mypaleta=['#BF812D', '#E2D7A1',  '#A8DFD4', '#35978F'] #darker colours

# %% [markdown]
# ##### Figure S2

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(15,12))
ax1=sns.scatterplot(data=statsmerge, x='count', y='Orthologs_norm', hue='Method', s=75, palette=mypaleta)

augustus = statsmerge[statsmerge['Method'] == 'Ab-initio'].reset_index(drop=True)
ensembl= statsmerge[statsmerge['Method'] == 'Ensembl'].reset_index(drop=True)
ncbi= statsmerge[statsmerge['Method'] == 'Ensembl']
up= statsmerge[statsmerge['Method'] == 'UniProt']

ra, pa = sp.stats.pearsonr(x=augustus['count'], y=augustus['Orthologs_norm'])
re, pe = sp.stats.pearsonr(x=ensembl['count'], y=ensembl['Orthologs_norm'])
rn, pn = sp.stats.pearsonr(x=ncbi['count'], y=ncbi['Orthologs_norm'])
ru, pu = sp.stats.pearsonr(x=up['count'], y=up['Orthologs_norm'])

print(str(ra)+' and pval:'+str(pa))
print(str(re)+' and pval:'+str(pe))
print(str(rn)+' and pval:'+str(pn))
print(str(ru)+' and pval:'+str(pu))

sns.despine()
ax.set_ylabel('Proportion of orthologous proteins', labelpad =22, size =27)
ax.set_xlabel('Number of proteins', labelpad=22, size=27)
plt.yticks(fontsize=25)
plt.xticks(fontsize=25)
plt.legend(bbox_to_anchor=(0.7, 0.85), loc='upper left', title= "", fontsize=20)

## Correlation line
import numpy as np
m, b = np.polyfit(augustus['count'], augustus['Orthologs_norm'], 1)
X_plot = np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '-', c='#BF812D')

plt.annotate('r'' = {:.2f}'.format(ra) + ', p = {:.3f}'.format(pa), xy=(0.6, 0.4), 
             xycoords='axes fraction', fontsize=27)

#for i, txt in enumerate(statsmerge['Species']):
 #   xpos=statsmerge['count'][i]
  #  ypos=statsmerge['Orthologs_norm'][i]
   # fs=12.5
    #ax.annotate(txt, (xpos + 100, ypos-0.003), fontsize=fs)
    
ax = plt.gca() # Get a matplotlib's axes instance
#plt.savefig('Prots-prop_with_Pearson.png', bbox_inches='tight', dpi=300)
#plt.close()
# Out:
# -0.7386502786748204 and pval:0.00019957501984025258
# 0.1512985528373248 and pval:0.5242927914861065
# 0.1512985528373248 and pval:0.5242927914861065
# 0.14423761448542358 and pval:0.5440486233481205
